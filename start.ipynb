# %%
# !python3 update_market_dataset.py
# !python3 train_model.py
# !python3 yaogu_model_v3.py
# Out:
# 读取已有数据集：output/a_share_labeled_dataset_with_auto_manual_label.csv
# 已有样本数：20646
# 已有日期范围：2024-07-02 00:00:00 -> 2026-04-30 00:00:00
# 登录 BaoStock...
# login success!
# 读取本地股票池：output/stock_pool.csv
# 股票池数量：300
#
# [1/300] 处理 sh.688001
# 688001 更新区间：2026-05-01 -> 2026-05-02
# 688001 没有新数据
# sh.688001 完成，样本数：385
#
# [2/300] 处理 sh.688002
# 688002 更新区间：2026-05-01 -> 2026-05-02
# 688002 没有新数据
# sh.688002 完成，样本数：385
#
# [3/300] 处理 sh.688003
# 688003 更新区间：2026-05-01 -> 2026-05-02
# 688003 没有新数据
# sh.688003 完成，样本数：385
#
# [4/300] 处理 sh.688004
# 688004 更新区间：2024-01-01 -> 2026-05-02
# sh.688004 失败：成交额过低：35289764
#
# [5/300] 处理 sh.688005
# 688005 更新区间：2026-05-01 -> 2026-05-02
# 688005 没有新数据
# sh.688005 完成，样本数：382
#
# [6/300] 处理 sh.688006
# 688006 更新区间：2026-05-01 -> 2026-05-02
# 688006 没有新数据
# sh.688006 完成，样本数：385
#
# [7/300] 处理 sh.688007
# 688007 更新区间：2024-01-01 -> 2026-05-02
# sh.688007 失败：成交额过低：79932204
#
# [8/300] 处理 sh.688008
# 688008 更新区间：2026-05-01 -> 2026-05-02
# 688008 没有新数据
# ...

# %%
# !streamlit run app.py
// 这是一个简单的 Streamlit 应用程序，用于展示股票市场数据分析和预测结果。
// 你可以根据需要修改和扩展这个应用程序的功能。
